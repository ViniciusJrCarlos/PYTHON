# %% [markdown]
# <a href="https://colab.research.google.com/github/ViniciusJrCarlos/PYTHON/blob/main/ipcaprecos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import html5lib
import os
import matplotlib.pyplot as plt
import seaborn as sns
from urllib.request import Request, urlopen
import numpy as np

# %%
req = Request("https://www.portalbrasil.net/ipca/", headers={'User-Agent': 'Google'})

# %%
pagina = urlopen(req).read()

# %%
ipca = pd.read_html(pagina)

# %%
ipca = ipca[1]

# %%
print(ipca)
# Out:
#         Mês Índice  ...                     Nº índiceDesde Jan/1993Dez/1992=1,00
#         Mês Do mês  ...           Acumulado Nº índiceDesde Jan/1993Dez/1992=1,00
#         Mês Do mês  ... Nos últimos12 meses Nº índiceDesde Jan/1993Dez/1992=1,00
# 0  Jun/2021     53  ...               83469                             1.486996
# 1  Mai/2021     83  ...               80559                             1.479156
# 2  Abr/2021     31  ...               67592                             1.466980
# 3  Mar/2021     93  ...               60993                             1.462447
# 4  Fev/2021     86  ...               51953                             1.448971
# 5  Jan/2021     25  ...               45591                             1.436616
#
# [6 rows x 5 columns]

# %%
ipca.head(10)
# Out:
#         Mês Índice  ...                     Nº índiceDesde Jan/1993Dez/1992=1,00
#         Mês Do mês  ...           Acumulado Nº índiceDesde Jan/1993Dez/1992=1,00
#         Mês Do mês  ... Nos últimos12 meses Nº índiceDesde Jan/1993Dez/1992=1,00
# 0  Jun/2021     53  ...               83469                             1.486996
# 1  Mai/2021     83  ...               80559                             1.479156
# 2  Abr/2021     31  ...               67592                             1.466980
# 3  Mar/2021     93  ...               60993                             1.462447
# 4  Fev/2021     86  ...               51953                             1.448971
# 5  Jan/2021     25  ...               45591                             1.436616
#
# [6 rows x 5 columns]

# %%
ipca.columns
# Out:
# MultiIndex([(                                 'Mês', ...),
#             (                              'Índice', ...),
#             (                              'Índice', ...),
#             (                              'Índice', ...),
#             ('Nº índiceDesde Jan/1993Dez/1992=1,00', ...)],
#            )

# %%
ipca.columns = ['mesano', 'indiceporcentagemmes', 'indiceporcentagemano',
       'indiceultimo12meses',
       'indiceacumuladodesde93']

# %%
ipca100 = ipca[0:20]

# %%
plt.title("Indice Nacional de Preços (IPCA) ")
plt.xlabel(" mês/ano ")
plt.ylabel(" indice do mês em (%) ")
#plt.style.use()
plt.bar(ipca100.mesano, ipca100.indiceporcentagemmes, label="IPCA", color = "green")
plt.rcParams['figure.figsize'] = (30,21)
 
#plt.xticks(ipca100.mesano)
 
plt.legend()

# %%
import pandas as pd
import html5lib
import os
import matplotlib.pyplot as plt
import seaborn as sns
from urllib.request import Request, urlopen
import numpy as np

# %%
codigo_bcb = 28565

# %%
url = 'http://api.bcb.gov.br/dados/serie/bcdata.sgs.{}/dados?formato=json'.format(codigo_bcb)

# %%
df = pd.read_json(url)

# %%
df
# Out:
#           data  valor
# 0   01/01/2012    7.9
# 1   01/04/2012    7.4
# 2   01/07/2012    6.9
# 3   01/10/2012    6.6
# 4   01/01/2013    7.6
# 5   01/04/2013    7.2
# 6   01/07/2013    7.0
# 7   01/10/2013    6.2
# 8   01/01/2014    7.0
# 9   01/04/2014    6.9
# 10  01/07/2014    6.9
# 11  01/10/2014    6.6
# 12  01/01/2015    8.0
# 13  01/04/2015    8.3
# 14  01/07/2015    9.0
# 15  01/10/2015    9.6
# 16  01/01/2016   11.4
# 17  01/04/2016   11.7
# 18  01/07/2016   12.3
# 19  01/10/2016   12.3
# 20  01/01/2017   14.2
# 21  01/04/2017   13.6
# 22  01/07/2017   13.2
# 23  01/10/2017   12.6
# 24  01/01/2018   13.8
# 25  01/04/2018   13.2
# 26  01/07/2018   12.5
# 27  01/10/2018   12.1
# 28  01/01/2019   13.2
# 29  01/04/2019   12.4
# 30  01/07/2019   11.9
# 31  01/10/2019   11.4
# 32  01/01/2020   12.4
# 33  01/04/2020   13.9
# 34  01/10/2020   14.8

# %%
#codigo_bcb = 28565
def consulta_bc(codigo_bcb):
  url = 'http://api.bcb.gov.br/dados/serie/bcdata.sgs.{}/dados?formato=json'.format(codigo_bcb)
  df = pd.read_json(url)
  return df

# %%
taxadesemprego2020 = consulta_bc(28565)

# %%
taxadesemprego2020.columns
# Out:
# Index(['data', 'valor'], dtype='object')

# %%
taxadesemprego2020 = taxadesemprego2020[0:20]

# %%
taxadesemprego2020 = '2020-01-01'

# %%
taxadesemprego2020
# Out:
# '2020-01-01'

# %%
#codigo_bcb = 433
def consulta_bc(codigo_bcb):
  url = 'http://api.bcb.gov.br/dados/serie/bcdata.sgs.{}/dados?formato=json'.format(codigo_bcb)
 
  df = pd.read_json(url)
 
  df['data'] = pd.to_datetime(df['data'], dayfirst=True)
  df.set_index('data', inplace=True)
  return df

# %%
taxadesemp = consulta_bc(28565)

# %%
taxadesemp
# Out:
#             valor
# data
# 2012-01-01    7.9
# 2012-04-01    7.4
# 2012-07-01    6.9
# 2012-10-01    6.6
# 2013-01-01    7.6
# 2013-04-01    7.2
# 2013-07-01    7.0
# 2013-10-01    6.2
# 2014-01-01    7.0
# 2014-04-01    6.9
# 2014-07-01    6.9
# 2014-10-01    6.6
# 2015-01-01    8.0
# 2015-04-01    8.3
# 2015-07-01    9.0
# 2015-10-01    9.6
# 2016-01-01   11.4
# 2016-04-01   11.7
# 2016-07-01   12.3
# 2016-10-01   12.3
# 2017-01-01   14.2
# 2017-04-01   13.6
# 2017-07-01   13.2
# 2017-10-01   12.6
# 2018-01-01   13.8
# 2018-04-01   13.2
# 2018-07-01   12.5
# 2018-10-01   12.1
# 2019-01-01   13.2
# 2019-04-01   12.4
# 2019-07-01   11.9
# 2019-10-01   11.4
# 2020-01-01   12.4
# 2020-04-01   13.9
# 2020-10-01   14.8

# %%
taxadesempano = consulta_bc(10799)

# %%
taxadesempano
# Out:
#             valor
# data
# 2001-10-01   25.8
# 2001-11-01   25.6
# 2001-12-01   29.2
# 2002-01-01   27.3
# 2002-02-01   28.2
# ...           ...
# 2015-10-01   20.7
# 2015-11-01   19.5
# 2015-12-01   22.9
# 2016-01-01   21.1
# 2016-02-01   20.9
#
# [173 rows x 1 columns]

# %%
taxadesempano.plot()

# %%
taxadesemp.plot()

# %%
fig, ax = plt.subplots()
ax.plot(taxadesemp)
ax.plot(taxadesempano)

# %%
# !pip install yfinance --upgrade --no-cache-dir
import yfinance as yf
# Out:
# ...
#      |████████████████████████████████| 6.3 MB 6.4 MB/s
# ...
#   Created wheel for yfinance: filename=yfinance-0.1.63-py2.py3-none-any.whl size=23919 sha256=22e76bffadf2d817a0fd61bb35280696102474b40d27060bf8cca19d07995023
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2n3nr1_8/wheels/fe/87/8b/7ec24486e001d3926537f5f7801f57a74d181be25b11157983
# Successfully built yfinance
# ...
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ...

# %%
import yfinance as yf

# %%
ibov = yf.download(tickers='^BVSP')[['Adj Close']]
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ibov_retorno = ibov.pct_change()

# %%
data_inicio = '2015-01-01'

# %%
ibov_retorno_acumulado = (1 + ibov_retorno[ibov_retorno.index >= data_inicio]).cumprod()
ibov_retorno_acumulado.iloc[0] = 1

# %%
ibov_retorno_acumulado
# Out:
#             Adj Close
# Date
# 2015-01-02   1.000000
# 2015-01-05   0.950207
# 2015-01-06   0.959886
# 2015-01-07   0.989122
# 2015-01-08   0.998720
# ...               ...
# 2021-07-23   2.500710
# 2021-07-26   2.519727
# 2021-07-27   2.491891
# 2021-07-28   2.525366
# 2021-07-29   2.513148
#
# [1623 rows x 1 columns]

# %%
cdi = consulta_bc(12)

# %%
cdi_acumulado = (1 + cdi[cdi.index >= data_inicio]/100).cumprod()

# %%
cdi_acumulado
cdi_acumulado.iloc[0] = 1

# %%
cdi_acumulado
# Out:
#                valor
# data
# 2015-01-02  1.000000
# 2015-01-05  1.000869
# 2015-01-06  1.001304
# 2015-01-07  1.001739
# 2015-01-08  1.002175
# ...              ...
# 2021-07-22  1.669614
# 2021-07-23  1.669884
# 2021-07-26  1.670153
# 2021-07-27  1.670423
# 2021-07-28  1.670692
#
# [1647 rows x 1 columns]

# %%
ibov_retorno_acumulado
# Out:
#             Adj Close
# Date
# 2015-01-02   1.000000
# 2015-01-05   0.950207
# 2015-01-06   0.959886
# 2015-01-07   0.989122
# 2015-01-08   0.998720
# ...               ...
# 2021-07-23   2.500710
# 2021-07-26   2.519727
# 2021-07-27   2.491891
# 2021-07-28   2.525366
# 2021-07-29   2.513148
#
# [1623 rows x 1 columns]

# %%
fig, ax = plt.subplots()
ax.plot(ibov_retorno_acumulado)
ax.plot(cdi_acumulado)
